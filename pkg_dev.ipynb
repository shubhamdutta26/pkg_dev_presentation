# %% [raw]
# ---
# title: '{{< fa brands r-project size=5x >}}<br>Packages Development'
# pagetitle: 'R - Packages Development'
# author:  'Shubham Dutta, Ph.D.'
# format:
#   revealjs:
#     height: 1080
#     width: 1920
# execute:
#   eval: false
#   echo: true
# ---

# %% [markdown]
# ## `devtools`: To Develop {{< fa brands r-project >}} Packages
#
# [https://devtools.r-lib.org/](https://devtools.r-lib.org/)
#
#
# ```{txt}
# # Install devtools from CRAN
# install.packages("devtools")
#
# # Or the development version from GitHub:
# # install.packages("devtools")
# devtools::install_github("r-lib/devtools")
# ```
#
# ```{txt}
# library("devtools")
# ```
#
#
#
# ## Let's create our first package
#
# ![](images/create_pak.png) ![](images/tree1.png)
#
# ## use_git()
#
# ![](images/git1.png) ![](images/git2.png)
#
# ## Our first function
#
# ![](images/c2f.png) ![](images/c2f_2.png)
#
# ## Our first function
#
# ![](images/c2f.png) ![](images/tree1.png)
#
# ## Our first function
#
# ![](images/use_r.png)
#
# ![](images/tree2.png)
#
# Copy + paste the code to **celsius_to_farenheit.R**
#
# ## Time for a test drive
#
# ::: {.fragment .fade-up}
# - `source("celsius_to_farenheit.R")`
# :::
#
# ::: {.fragment .fade-up}
# - Send the function to the `console` of RStudio
# :::
#
# ## load_all()
#
# ::: {.fragment .strike}
# - `source("celsius_to_farenheit.R")`
# :::
#
# ::: {.fragment .strike}
# - Send the function to the `console` of RStudio
# :::
#
# ::: {.fragment .fade-up}
# ![](images/load_all.png)
#
# Hotkey: `Cmd/Ctrl + Shift + L`
# :::
